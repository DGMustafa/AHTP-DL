# %% [markdown]
# # Run each cell one by one

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# %cd /content/drive/My Drive/Colab Notebooks/
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
#In the following code  temp.txt is the file in which the peptides is  
# Replace temp.txt with any file which need to be calculate DPC features.
# The  file must be in the folder in which all code files are
# peptides must be in fasta format
# Examples of fasta format file:

#    >peptide_0
#    AAAWWN
#    >peptide_1
#    ANAVRN

# where "peptide" word can be changed or anything else but "_" , and  ">" must same as it is and the number of example must be in ascending order (i.e. 0,1,2,3....) 
# As a output four files will be generated (DPC-Features-gap-0,DPC-Features-gap-1,DPC-Features-gap-2,DPC-Features-gap-4) which contains DPC features with gap 0,1,2,3. Note that you can change the output file names as well

# !python g-gap.py -g 0 -i allseq.csv -o DPC-Features-gap-0.csv
# !python g-gap.py -g 1 -i allseq.csv -o DPC-Features-gap-1.csv
# !python g-gap.py -g 2 -i allseq.csv -o DPC-Features-gap-2.csv
# !python g-gap.py -g 3 -i allseq.csv -o DPC-Features-gap-3.csv
# Out:
# python3: can't open file 'g-gap.py': [Errno 2] No such file or directory
# python3: can't open file 'g-gap.py': [Errno 2] No such file or directory
# python3: can't open file 'g-gap.py': [Errno 2] No such file or directory
# python3: can't open file 'g-gap.py': [Errno 2] No such file or directory
